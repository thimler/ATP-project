# %%
#Libraries imports
import pandas as pd

import camelot

import requests

from bs4 import BeautifulSoup

import folium

import json

import sys


import geojson

import datapackage 

import datetime

# %%
# Request actual top 200 ATP male players en espn site
page = requests.get("https://www.espn.com/tennis/rankings")

# %%
# Scrapping data using BeautifulSoup library
soup = BeautifulSoup(page.content, 'html.parser')

# Look for the table of interest
print('Classes of each table:')
for table in soup.find_all('table'):
    print(table.get('class'))
# Out:
# Classes of each table:
# ['Table', 'Table--align-right']

# %%
# Extract data from the table
tab = soup.find("table",{"class":"Table--align-right"})

# Isolate names of the countries corresponding to the flag
nations = soup.find_all(class_ = "Image Logo Logo__sm",attrs ={'title'})

# %%
# Creating the dataframe
df = pd.DataFrame(columns=['Rankings','Player', 'Country', 'Age'])

# and extract corresponding data
for row in tab.tbody.find_all('tr'):    
    # Find all data for each column   
    # Find all data for each column
    columns = row.find_all('td')
    
    if(columns != []):
        rankings = columns[0].text.strip()
        player = columns[2].text.strip('&0.')
        country = columns[2].find('Image Logo Logo__sm')
        age = columns[4].text.strip('&0.')
        

        df = df.append({'Rankings': rankings,  'Player': player, 'Age': age,'Country': country}, ignore_index=True)

# %%
# Assign nationality to player based on the flag
for i in range(150):
    df['Country'][i] = nations[i]['title']

df.reset_index(drop=True,inplace=True)

# %%
# Count number of top 200 players by country
bestcountries = df.groupby('Country').count()['Age']
bestcountries = pd.DataFrame(bestcountries)
bestcountries['index'] = bestcountries.index
bestcountries = bestcountries.drop('index',axis = 1)
bestcountries["Name"] = bestcountries.index

# %%
# Setting up the world countries data URL
url = 'https://raw.githubusercontent.com/python-visualization/folium/master/examples/data'
country_shapes = f'{url}/world-countries.json'

# %%
country_geo = 'world-countries.json'
wc = 'countries.geojson'

# Extracting A3 and A2 country names
codes = pd.read_excel('codes.xlsx')

# %%
bestcountries = bestcountries[['Name', 'Age']]
country = pd.read_csv('data_cod.csv')
country = country.merge(bestcountries,how='left', left_on='Name', right_on='Name')
country.fillna(0,inplace = True)

# %%
bestcountries.head()
# Out:
#                 Name  Age
# Country
# Argentina  Argentina   12
# Australia  Australia   10
# Belarus      Belarus    2
# Belgium      Belgium    2
# Bolivia      Bolivia    1

# %%
results = codes.merge(country,right_on='Code',left_on='Code-2' )
results = results[['Country','Age']]
results[['Age']] = results[['Age']].astype(int)

# %%
m = folium.Map(location=[45.5236, -122.6750])

folium.Choropleth(
    geo_data=country_shapes,
    name='choropleth',
    data=results,
    columns=["Country", "Age"],
    key_on='feature.properties.name',
    fill_color="YlGn",
    nan_fill_color='white',
    fill_opacity=0.7,
    line_opacity=.1,
    legend_name="Top 200 Players repartition",
).add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# c:\Users\theoi\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# c:\Users\theoi\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      60
# ---> 61     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62         af, socktype, proto, canonname, sa = res
#
# c:\Users\theoi\anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# c:\Users\theoi\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# c:\Users\theoi\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#
# c:\Users\theoi\anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     977         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 978             conn.connect()
#     979
#
# c:\Users\theoi\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     308         # Add certificate verification
# --> 309         conn = self._new_conn()
#     310         hostname = self.host
#
# c:\Users\theoi\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     170         except SocketError as e:
# --> 171             raise NewConnectionError(
#     172                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x000002A212D29130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# c:\Users\theoi\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# c:\Users\theoi\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     725
# --> 726             retries = retries.increment(
#     727                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# c:\Users\theoi\anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     445         if new_retry.is_exhausted():
# --> 446             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     447
#
# MaxRetryError: HTTPSConnectionPool(host='raw.githubusercontent.com', port=443): Max retries exceeded with url: /python-visualization/folium/master/examples/data/world-countries.json (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002A212D29130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-15-76c115ba56ac> in <module>
#       1 m = folium.Map(location=[45.5236, -122.6750])
#       2
# ----> 3 folium.Choropleth(
#       4     geo_data=country_shapes,
#       5     name='choropleth',
#
# c:\Users\theoi\anaconda3\lib\site-packages\folium\features.py in __init__(self, geo_data, data, columns, key_on, bins, fill_color, nan_fill_color, fill_opacity, nan_fill_opacity, line_color, line_weight, line_opacity, name, legend_name, overlay, control, show, topojson, smooth_factor, highlight, **kwargs)
#    1287                 smooth_factor=smooth_factor)
#    1288         else:
# -> 1289             self.geojson = GeoJson(
#    1290                 geo_data,
#    1291                 style_function=style_function,
#
# c:\Users\theoi\anaconda3\lib\site-packages\folium\features.py in __init__(self, data, style_function, highlight_function, name, overlay, control, show, smooth_factor, tooltip, embed, popup, zoom_on_click, marker)
#     497         self.marker = marker
#     498
# --> 499         self.data = self.process_data(data)
#     500
#     501         if self.style or self.highlight:
#
# c:\Users\theoi\anaconda3\lib\site-packages\folium\features.py in process_data(self, data)
#     527                 if not self.embed:
#     528                     self.embed_link = data
# --> 529                 return requests.get(data).json()
#     530             elif data.lstrip()[0] in '[{':  # This is a GeoJSON inline string
#     531                 self.embed = True
#
# c:\Users\theoi\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# c:\Users\theoi\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# c:\Users\theoi\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# c:\Users\theoi\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# c:\Users\theoi\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='raw.githubusercontent.com', port=443): Max retries exceeded with url: /python-visualization/folium/master/examples/data/world-countries.json (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002A212D29130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))

# %%
atp = pd.read_csv('Data.csv/Data.csv',encoding='latin-1')
atp2 = pd.read_csv('Data.csv/ATP2.csv',encoding='latin-1')
# Out:
# c:\Users\theoi\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (11,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
atp2 = atp2[['loser_name','winner_name','loser_age','winner_age','tourney_date']]
atp2 = atp2[atp2.tourney_date >= 20000103]
atp2.head()
# Out:
#               loser_name          winner_name  loser_age  winner_age  \
# 110260    Arnaud Clement       Thomas Enqvist      22.05       25.81
# 110261  Jens Knippschild        Roger Federer      24.88       18.40
# 110262     Wayne Arthurs  Jan Michael Gambill      28.80       22.58
# 110263       Andrew Ilie   Sebastien Grosjean      23.71       21.60
# 110264      Scott Draper        Magnus Norman      25.58       23.59
#
#         tourney_date
# 110260      20000103
# 110261      20000103
# 110262      20000103
# 110263      20000103
# 110264      20000103

# %%
atp2['loser_age'] = atp2['loser_age'].astype(str).str[:-3]
atp2['winner_age'] = atp2['winner_age'].astype(str).str[:-3]
atp2.head()
# Out:
#               loser_name          winner_name loser_age winner_age  \
# 110260    Arnaud Clement       Thomas Enqvist        22         25
# 110261  Jens Knippschild        Roger Federer        24          1
# 110262     Wayne Arthurs  Jan Michael Gambill         2         22
# 110263       Andrew Ilie   Sebastien Grosjean        23          2
# 110264      Scott Draper        Magnus Norman        25         23
#
#         tourney_date
# 110260      20000103
# 110261      20000103
# 110262      20000103
# 110263      20000103
# 110264      20000103

# %%
atp = atp[['Tournament','Date','Series','Surface','Round','Best of','Winner','Loser','WRank','LRank']]

atp['Winner'] = atp['Winner'].str[:-3]
atp['Loser'] = atp['Loser'].str[:-3]
atp.head()
# Out:
#                            Tournament       Date         Series Surface  \
# 0  Australian Hardcourt Championships  3/01/2000  International    Hard
# 1  Australian Hardcourt Championships  3/01/2000  International    Hard
# 2  Australian Hardcourt Championships  3/01/2000  International    Hard
# 3  Australian Hardcourt Championships  3/01/2000  International    Hard
# 4  Australian Hardcourt Championships  3/01/2000  International    Hard
#
#        Round  Best of    Winner        Loser WRank LRank
# 0  1st Round        3   Dosedel     Ljubicic    63    77
# 1  1st Round        3   Enqvist      Clement     5    56
# 2  1st Round        3    Escude   Baccanello    40   655
# 3  1st Round        3   Federer  Knippschild    65    87
# 4  1st Round        3  Fromberg   Woodbridge    81   198

# %%
atp['Date'] = pd.to_datetime(atp['Date'],  dayfirst=True)
atp['Date'] = atp['Date'].astype(str).str.replace("-","")
atp.head()
# Out:
#                            Tournament      Date         Series Surface  \
# 0  Australian Hardcourt Championships  20000103  International    Hard
# 1  Australian Hardcourt Championships  20000103  International    Hard
# 2  Australian Hardcourt Championships  20000103  International    Hard
# 3  Australian Hardcourt Championships  20000103  International    Hard
# 4  Australian Hardcourt Championships  20000103  International    Hard
#
#        Round  Best of    Winner        Loser WRank LRank
# 0  1st Round        3   Dosedel     Ljubicic    63    77
# 1  1st Round        3   Enqvist      Clement     5    56
# 2  1st Round        3    Escude   Baccanello    40   655
# 3  1st Round        3   Federer  Knippschild    65    87
# 4  1st Round        3  Fromberg   Woodbridge    81   198

# %%
atp['Date'] = atp['Date'].str.replace("-","")
# Out:
#    ATP  Location                          Tournament      Date         Series  \
# 0    1  Adelaide  Australian Hardcourt Championships  20000301  International
# 1    1  Adelaide  Australian Hardcourt Championships  20000301  International
# 2    1  Adelaide  Australian Hardcourt Championships  20000301  International
# 3    1  Adelaide  Australian Hardcourt Championships  20000301  International
# 4    1  Adelaide  Australian Hardcourt Championships  20000301  International
#
#      Court Surface Round  Best of       Winner  ... UBW UBL LBW  LBL  SJW  \
# 0  Outdoor    Hard    64        3   Dosedel S.  ... NaN NaN NaN  NaN  NaN
# 1  Outdoor    Hard    64        3   Enqvist T.  ... NaN NaN NaN  NaN  NaN
# 2  Outdoor    Hard    64        3    Escude N.  ... NaN NaN NaN  NaN  NaN
# 3  Outdoor    Hard    64        3   Federer R.  ... NaN NaN NaN  NaN  NaN
# 4  Outdoor    Hard    64        3  Fromberg R.  ... NaN NaN NaN  NaN  NaN
#
#    SJL  MaxW  MaxL  AvgW  AvgL
# 0  NaN   NaN   NaN   NaN   NaN
# 1  NaN   NaN   NaN   NaN   NaN
# 2  NaN   NaN   NaN   NaN   NaN
# 3  NaN   NaN   NaN   NaN   NaN
# 4  NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 54 columns]

# %%
#Focus on Masters and Grand slam tournament, get rid of qualification round and Masters
atp = atp[(atp.Round != 'Round Robin') & (atp.Round != '0th Round')]
atp['Round'] = atp['Round'].astype('category')
atp['Round'].replace({"1st Round": "64", "2nd Round": "32","3rd Round":"16", "4th Round" : "8", "Quarterfinals" : "4", "Semifinals": "2", "The Final":"1"}, inplace=True)

# %%
atp.head()
# Out:
#    ATP  Location                          Tournament       Date  \
# 0    1  Adelaide  Australian Hardcourt Championships 2000-03-01
# 1    1  Adelaide  Australian Hardcourt Championships 2000-03-01
# 2    1  Adelaide  Australian Hardcourt Championships 2000-03-01
# 3    1  Adelaide  Australian Hardcourt Championships 2000-03-01
# 4    1  Adelaide  Australian Hardcourt Championships 2000-03-01
#
#           Series    Court Surface Round  Best of       Winner  ... UBW UBL  \
# 0  International  Outdoor    Hard    64        3   Dosedel S.  ... NaN NaN
# 1  International  Outdoor    Hard    64        3   Enqvist T.  ... NaN NaN
# 2  International  Outdoor    Hard    64        3    Escude N.  ... NaN NaN
# 3  International  Outdoor    Hard    64        3   Federer R.  ... NaN NaN
# 4  International  Outdoor    Hard    64        3  Fromberg R.  ... NaN NaN
#
#   LBW  LBL  SJW  SJL  MaxW  MaxL  AvgW  AvgL
# 0 NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN
# 1 NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN
# 2 NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN
# 3 NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN
# 4 NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 54 columns]

# %%
surface = atp.groupby(['Surface','Winner'])['Winner']\
             .count()\
             .reset_index(name='count') \
             .sort_values(['count'], ascending=False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
top = surface.groupby('Surface').head(5)

top
# Out:
#      Surface        Winner  count
# 1470    Hard    Federer R.    622
# 1436    Hard   Djokovic N.    469
# 1805    Hard    Roddick A.    402
# 1719    Hard     Murray A.    369
# 1722    Hard      Nadal R.    363
# 613     Clay      Nadal R.    351
# 384     Clay     Ferrer D.    293
# 225     Clay    Almagro N.    262
# 680     Clay    Robredo T.    249
# 385     Clay  Ferrero J.C.    221
# 970    Grass    Federer R.    147
# 1023   Grass     Hewitt L.    103
# 1130   Grass     Murray A.     90
# 1186   Grass    Roddick A.     82
# 1043   Grass   Karlovic I.     66
# 57    Carpet    Federer R.     46
# 167   Carpet      Safin M.     46
# 121   Carpet   Ljubicic I.     45
# 44    Carpet  Davydenko N.     38
# 209   Carpet    Youzhny M.     38

# %%
sns.barplot(x="Winner", y ="count", hue = 'Surface', data=top)
plt.ylim(0, 500)
# Out:
# (0.0, 500.0)

# %%
features = atp
feat = pd.DataFrame(features)

# %%
 from sklearn import preprocessing

# Use numpy to convert to arrays
import numpy as np

# Labels are the values we want to predict

# Saving feature names for later use
feature_list = list(features.columns)
# Convert to numpy array

tournament = feat['Tournament'].tolist()
features['Tournament'] = pd.get_dummies(tournament)

series = feat['Series'].tolist()
features['Series'] = pd.get_dummies(series)

surface = feat['Surface'].tolist()
features['Surface'] = pd.get_dummies(surface)

round = feat['Round'].tolist()
features['Round'] = pd.get_dummies(round)


loser = feat['Loser'].tolist()
features['Loser'] = pd.get_dummies(loser)

winner = feat['Winner'].tolist()
features['Winner'] = pd.get_dummies(winner)
# Remove the labels from the features

labels = features['Winner']
# axis 1 refers to the columns
features= features.drop(['Winner','Date'], axis = 1)

# %%
labels
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 46647    1
# 46648    1
# 46649    1
# 46650    1
# 46651    1
# Name: Winner, Length: 46652, dtype: uint8

# %%
# Using Skicit-learn to split data into training and testing sets
from sklearn.model_selection import train_test_split
# Split the data into training and testing sets
train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size = 0.25, random_state = 42)

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
# Train the model on training data
rf.fit(train_features, train_labels);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-109-bc774a9d8239> in <module>
#       4 rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
#       5 # Train the model on training data
# ----> 6 rf.fit(train_features, train_labels);
#
# c:\Users\theoi\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     329         if issparse(y):
#     330             raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 331         X, y = self._validate_data(
#     332             X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     333         )
#
# c:\Users\theoi\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     594                 y = check_array(y, input_name="y", **check_y_params)
#     595             else:
# --> 596                 X, y = check_X_y(X, y, **check_params)
#     597             out = X, y
#     598
#
# c:\Users\theoi\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1072         )
#    1073
# -> 1074     X = check_array(
#    1075         X,
#    1076         accept_sparse=accept_sparse,
#
# c:\Users\theoi\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     854                     array = array.astype(dtype, casting="unsafe", copy=False)
#     855                 else:
# --> 856                     array = np.asarray(array, order=order, dtype=dtype)
#     857             except ComplexWarning as complex_warning:
#     858                 raise ValueError(
#
# c:\Users\theoi\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# c:\Users\theoi\anaconda3\lib\site-packages\pandas\core\generic.py in __array__(self, dtype)
#    1779
#    1780     def __array__(self, dtype=None) -> np.ndarray:
# -> 1781         return np.asarray(self._values, dtype=dtype)
#    1782
#    1783     def __array_wrap__(self, result, context=None):
#
# c:\Users\theoi\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: could not convert string to float: 'NR'

# %%
# Use the forest's predict method on the test data
predictions = rf.predict(test_features)
# Calculate the absolute errors
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-89-4ede65a4f641> in <module>
#       1 # Use the forest's predict method on the test data
# ----> 2 predictions = rf.predict(test_features)
#       3 # Calculate the absolute errors
#
# c:\Users\theoi\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in predict(self, X)
#     987             The predicted values.
#     988         """
# --> 989         check_is_fitted(self)
#     990         # Check data
#     991         X = self._validate_X_predict(X)
#
# c:\Users\theoi\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1343
#    1344     if not fitted:
# -> 1345         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1346
#    1347
#
# NotFittedError: This RandomForestRegressor instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.
